# %% [markdown]
# <a href="https://colab.research.google.com/github/Rickymuhindo/Rickymuhindo/blob/main/comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install qiskit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 33.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 52.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.4/39.4 MB 16.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.5/107.5 kB 7.1 MB/s eta 0:00:00
# ...

# %%
pip install qiskit-machine-learning
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.8/97.8 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.6/308.6 kB 11.8 MB/s eta 0:00:00
# ...
#   Created wheel for fastdtw: filename=fastdtw-0.3.4-cp310-cp310-linux_x86_64.whl size=512548 sha256=7bcd951cde81d4a71bfda7ca20ec3450d0b432190bbe231949f67827526ad597
#   Stored in directory: /root/.cache/pip/wheels/73/c8/f7/c25448dab74c3acf4848bc25d513c736bb93910277e1528ef4
# Successfully built fastdtw
# ...

# %%
pip install scikit-learn

# %%
pip install matplotlib

# %%
pip install numpy

# %%
pip install pip --upgrade
# Out:
# ...
#   Using cached pip-24.2-py3-none-any.whl.metadata (3.6 kB)
# Using cached pip-24.2-py3-none-any.whl (1.8 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...

# %%
pip install pip --upgrade --user

# %%
pip install qiskit-aer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 43.8 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for QSVm
qsvm_accuracies = [0.84, 0.76, 0.53, 0.92, 0.83]
qsvm_training_times = [1, 1, 1, 1, 1]
qsvm_prediction_times = [0.92, 0.87, 1, 0.81, 0.93]

# Data for SVM
svm_accuracies = np.array([0.80, 0.73, 0.52, 0.44, 0.46])
svm_training_times = np.array([0.0053, 0.0036, 0.0071, 0.0142, 0.0255])
svm_prediction_times = np.array([0.0007, 0.0008, 0.0021, 0.0028, 0.0063])

# Create subplots
fig, axs = plt.subplots(3, 1, figsize=(10, 15))

# Plot accuracies
axs[0].hist([qsvm_accuracies, svm_accuracies], bins=np.arange(0.4, 1.0, 0.1), label=['QSVm', 'SVM'], alpha=0.7)
axs[0].set_title('Comparison of Accuracies')
axs[0].set_xlabel('Accuracy')
axs[0].set_ylabel('Frequency')
axs[0].legend()

# Plot training times
axs[1].hist([qsvm_training_times, svm_training_times], bins=10, label=['QSVm', 'SVM'], alpha=0.7)
axs[1].set_title('Comparison of Training Times')
axs[1].set_xlabel('Training Time (seconds)')
axs[1].set_ylabel('Frequency')
axs[1].legend()

# Plot prediction times
axs[2].hist([qsvm_prediction_times, svm_prediction_times], bins=10, label=['QSVm', 'SVM'], alpha=0.7)
axs[2].set_title('Comparison of Prediction Times')
axs[2].set_xlabel('Prediction Time (seconds)')
axs[2].set_ylabel('Frequency')
axs[2].legend()

# Adjust layout
plt.tight_layout()
plt.show()
